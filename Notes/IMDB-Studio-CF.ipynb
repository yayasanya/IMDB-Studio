# %%
import pandas as pd
data = pd.read_csv('IMDB-Movie-Data1.csv')
data_indexed = pd.read_csv('IMDB-Movie-Data1.csv',index_col='Title')

# %%
# If you are having trouble reading your file, try finding the path.  
#Right click on your data set, on the pop-up menu select "Copy Path" then paste it into your read_csv() function.

# %% [markdown]
# ## Part 1: Series 101 (Exercises)

# %%
s1 = pd.Series([10, 20, 30, 40, 50])
print("The series values are:", s1.values)
print("The series index values are:", s1.index.values)
# Out:
# The series values are: [10 20 30 40 50]
# The series index values are: [0 1 2 3 4]

# %%
s2 = pd.Series([80, 93, 78, 85, 97], index=["English", "Science", "Social", "Tmail", "Maths"])
print("The Marks obtained by student are", s2)
# Out:
# The Marks obtained by student are English    80
# Science    93
# Social     78
# Tmail      85
# Maths      97
# dtype: int64

# %%
s1[1:4]
# Out:
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
s2["Tmail"]
# Out:
# 85

# %%
dict_fruits = {"Orange":80, "Apples":210, "Bananas":50, "Grapes":90, "Watermelon":70}
fruits = pd.Series(dict_fruits)
print("Fruits and prices \n", fruits)
# Out:
# Fruits and prices
#  Orange         80
# Apples        210
# Bananas        50
# Grapes         90
# Watermelon     70
# dtype: int64

# %%
print("The price per kg of grapes is:", fruits["Grapes"])
# Out:
# The price per kg of grapes is: 90

# %%
df_marks = pd.DataFrame(s2, columns=["Student1"])
print("The dataframe created from the series is: \n", df_marks)
# Out:
# The dataframe created from the series is:
#           Student1
# English        80
# Science        93
# Social         78
# Tmail          85
# Maths          97

# %%
height = pd.Series([5.3, 6.2, 5.8, 5.0, 5.5], index=["Person 1", "Person 2", "Person 3", "Person 4", "Person 5"])
weight = pd.Series([65, 89, 75, 60, 59], index=["Person 1", "Person 2", "Person 3", "Person 4", "Person 5"])
df_person = pd.DataFrame({"height": height, "weight":weight})
print("The Person table details are: \n", df_person)
# Out:
# The Person table details are:
#            height  weight
# Person 1     5.3      65
# Person 2     6.2      89
# Person 3     5.8      75
# Person 4     5.0      60
# Person 5     5.5      59

# %% [markdown]
# ## Part 2: Data Analysis of IMDB movies data -- Studio

# %%
# The studio will continue working through the "A Comprehensive Guide To Data Analysis using Pandas: Hands-On Data Analysis on IMDB movies data" in the DataFrame section

# Blocks have been created for your code

# Follow the link in the article to download the dataset from https://www.kaggle.com/PromptCloudHQ/imdb-data.  Link contained within the article.

# %% [markdown]
# ### 1. Read data

# %%
# import pandas as pd

# load your file into your notebook.
# Tip: keep you current jupyter lab notebook and any corresponding resources in the same directory.  It will make importing your files easier and help you stay organized. 

# Read data from .csv file

# %%
# Read data with specified explicit index

print(data_indexed)
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# ### 2. View Data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# Use the head() function to view the first 5 rows of the data set

#data.head()

data.head(14)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 7      8                                 Mindhorn                      Comedy
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
# ...

# %%
# Use the tail() function to view the last 5 rows of the data set

data.tail()
# Out:
#      Rank                   Title                  Genre  \
# 995   996    Secret in Their Eyes    Crime,Drama,Mystery
# 996   997         Hostel: Part II                 Horror
# 997   998  Step Up 2: The Streets    Drama,Music,Romance
# 998   999            Search Party       Adventure,Comedy
# 999  1000              Nine Lives  Comedy,Family,Fantasy
#
#                                            Description          Director  \
# 995  A tight-knit team of rising investigators, alo...         Billy Ray
# 996  Three American college students studying abroa...          Eli Roth
# 997  Romantic sparks occur between two dance studen...        Jon M. Chu
# 998  A pair of friends embark on a mission to reuni...    Scot Armstrong
# 999  A stuffy businessman finds himself trapped ins...  Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 995  Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...  2015
# ...

# %% [markdown]
# ### 3. Understand basic information about the data
# #### As we go through this section, write your own definitions of what each function does as a comment in the code box.

# %%
# The info() function: 

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# shape:

data.shape
# Out:
# (1000, 12)

# %%
# columns:

data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
# The describe() function: 

data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %% [markdown]
# ### 4. Data Selection -- Indexing and Slicing

# %%
#  Extract data as series

genre = data["Genre"]

# %%
data[["Genre"]]
some_cols = data[["Title", "Genre", "Actors", "Director", "Rating"]]

# %%
# Extract data using rows

# loc function

data_indexed.loc[["Suicide Squad"]][["Genre", "Actors", "Director", "Rating", "Revenue (Millions)"]]
# Out:
#                                   Genre  \
# Title
# Suicide Squad  Action,Adventure,Fantasy
#
#                                                           Actors    Director  \
# Title
# Suicide Squad  Will Smith, Jared Leto, Margot Robbie, Viola D...  David Ayer
#
#                Rating  Revenue (Millions)
# Title
# Suicide Squad     6.2              325.02

# %%
# iloc function

data.iloc[10:15][["Title", "Rating", "Revenue (Millions)"]]
# Out:
#                                       Title  Rating  Revenue (Millions)
# 10  Fantastic Beasts and Where to Find Them     7.5              234.02
# 11                           Hidden Figures     7.8              169.27
# 12                                Rogue One     7.9              532.17
# 13                                    Moana     7.7              248.75
# 14                                 Colossal     6.4                2.87

# %% [markdown]
# ### 5. Data Selection - Based on Conditional Filtering

# %%
data[((data["Year"] >= 2010) & (data["Year"] <= 2016))
      & (data["Rating"] < 6.0)
      & (data["Revenue (Millions)"] > data["Revenue (Millions)"].quantile(0.95))]
# Out:
#      Rank                       Title                    Genre  \
# 941   942  The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 941                124     4.9  192740              300.52       58.0

# %%
# Note: The article is expecting more than 1 Twilight movie.  Try manipulating the quantile value.

# %% [markdown]
# ### Testing

# %%
data[((data["Year"] >= 2010) & (data["Year"] <= 2016))
      & (data["Rating"] < 6.0)
      & (data["Revenue (Millions)"] > data["Revenue (Millions)"].quantile(0.943))]
# Out:
#      Rank                                      Title                    Genre  \
# 366   367  The Twilight Saga: Breaking Dawn - Part 2  Adventure,Drama,Fantasy
# 941   942                 The Twilight Saga: Eclipse  Adventure,Drama,Fantasy
#
#                                            Description     Director  \
# 366  After the birth of Renesmee, the Cullens gathe...  Bill Condon
# 941  As a string of mysterious killings grips Seatt...  David Slade
#
#                                                 Actors  Year  \
# 366  Kristen Stewart, Robert Pattinson, Taylor Laut...  2012
# 941  Kristen Stewart, Robert Pattinson, Taylor Laut...  2010
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 366                115     5.5  194329              292.30       52.0
# 941                124     4.9  192740              300.52       58.0
